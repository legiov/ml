# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import warnings
warnings.simplefilter('ignore')
from sklearn import neighbors

# %%
data = pd.DataFrame([[0,0,0],[0.2,0.1,0], [1,0,0], [2,1,1],[2.5,0.9,1], [3,1,1]], columns = ['x','y', 'target'])

# %%
data
# Out:
#      x    y  target
# 0  0.0  0.0       0
# 1  0.2  0.1       0
# 2  1.0  0.0       0
# 3  2.0  1.0       1
# 4  2.5  0.9       1
# 5  3.0  1.0       1

# %%
X = data.drop('target', axis=1)
Y = data['target']

# %%
neigh = neighbors.KNeighborsClassifier(n_neighbors=3)
neigh.fit(X, Y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
for item in np.linspace(0, 3, 10):
    x = item
    y = item*0.25
    plt.figure(figsize=(5,5))    
    red = data[data.target == 1]
    blue = data[data.target == 0]
    red_prob = round(neigh.predict_proba([[x, y]])[0][1], 2) * 100
    blue_prob = round(neigh.predict_proba([[x, y]])[0][0], 2) * 100
    plt.title(f'Красный на {red_prob} %, синий на {blue_prob} %')
    plt.xlabel('Значение признака x')
    plt.ylabel('Значение признака y')
    plt.scatter(red.x.values, red.y.values, c='r')
    plt.scatter(blue.x.values, blue.y.values, c='b')
    plt.scatter(x, y, c='g')
    plt.grid()
    plt.show()

# %%
neigh = neighbors.KNeighborsClassifier(n_neighbors=3, weights='distance')
neigh.fit(X, Y)
# Out:
# KNeighborsClassifier(n_neighbors=3, weights='distance')

# %%
for item in np.linspace(0, 3, 10):
    x = item
    y = item*0.25
    plt.figure(figsize=(5,5))    
    red = data[data.target == 1]
    blue = data[data.target == 0]
    red_prob = round(neigh.predict_proba([[x, y]])[0][1], 2) * 100
    blue_prob = round(neigh.predict_proba([[x, y]])[0][0], 2) * 100
    plt.title(f'Красный на {red_prob} %, синий на {blue_prob} %')
    plt.xlabel('Значение признака x')
    plt.ylabel('Значение признака y')
    plt.scatter(red.x.values, red.y.values, c='r')
    plt.scatter(blue.x.values, blue.y.values, c='b')
    plt.scatter(x, y, c='g')
    plt.grid()
    plt.show()
