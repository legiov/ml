# %%
import pandas as pd
import seaborn as sns
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN

# %%
df = pd.read_csv('data/housing.csv')
df.head()
# Out:
#        year      price
# 0  0.081091  23.790515
# 1  9.483270  10.784598
# 2  9.901805  10.003782
# 3  1.930438  21.879849
# 4  1.618601  21.851806

# %%
sns.scatterplot(data=df, x='year', y='price')
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
gmm = GaussianMixture(n_components=3, random_state=42)
gmm.fit(df)
prediction = gmm.predict(df)

# %%
sns.scatterplot(data=df, x='year', y='price', hue=prediction)
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
k_means = KMeans(n_clusters=3, random_state=42)
k_means.fit(df)
prediction = k_means.predict(df)

# %%
sns.scatterplot(data=df, x='year', y='price', hue=prediction)
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
dbs = DBSCAN(eps = 1.15, min_samples = 2)
dbs.fit(df)
prediction = dbs.labels_

sns.scatterplot(data=df, x='year', y='price', hue=prediction)
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_23451/3612072019.py in <module>
#       4 )
#       5
# ----> 6 aggcl.fit(X2)
#
# NameError: name 'X2' is not defined
